# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, log_loss
from fastai.tabular.all import *

# %%
from autogluon.tabular import *

# %%
path = untar_data(URLs.ADULT_SAMPLE)
path.ls()
# Out:
# (#3) [Path('C:/Users/Ali-Akber/.fastai/data/adult_sample/adult.csv'),Path('C:/Users/Ali-Akber/.fastai/data/adult_sample/export.pkl'),Path('C:/Users/Ali-Akber/.fastai/data/adult_sample/models')]

# %%
aipred = Path('C:/Users/Ali-Akber/Desktop/adult.csv')

# %%
df = pd.read_csv(path/'adult.csv')
db = pd.read_csv(aipred)
print(df.shape)
df.head()
# Out:
# (32561, 15)
#    age          workclass  fnlwgt     education  education-num  \
# 0   49            Private  101320    Assoc-acdm           12.0
# 1   44            Private  236746       Masters           14.0
# 2   38            Private   96185       HS-grad            NaN
# 3   38       Self-emp-inc  112847   Prof-school           15.0
# 4   42   Self-emp-not-inc   82297       7th-8th            NaN
#
#         marital-status        occupation    relationship                 race  \
# 0   Married-civ-spouse               NaN            Wife                White
# 1             Divorced   Exec-managerial   Not-in-family                White
# 2             Divorced               NaN       Unmarried                Black
# 3   Married-civ-spouse    Prof-specialty         Husband   Asian-Pac-Islander
# 4   Married-civ-spouse     Other-service            Wife                Black
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country salary
# 0   Female             0          1902              40   United-States  >=50k
# 1     Male         10520             0              45   United-States  >=50k
# 2   Female             0             0              32   United-States   <50k
# 3     Male             0             0              40   United-States  >=50k
# 4   Female             0             0              50   United-States   <50k

# %%
db.head()
# Out:
#    age          workclass  fnlwgt     education  education-num  \
# 0   49            Private  101320    Assoc-acdm           12.0
# 1   44            Private  236746       Masters           14.0
# 2   38            Private   96185       HS-grad            NaN
# 3   38       Self-emp-inc  112847   Prof-school           15.0
# 4   42   Self-emp-not-inc   82297       7th-8th            NaN
#
#         marital-status        occupation    relationship                 race  \
# 0   Married-civ-spouse               NaN            Wife                White
# 1             Divorced   Exec-managerial   Not-in-family                White
# 2             Divorced               NaN       Unmarried                Black
# 3   Married-civ-spouse    Prof-specialty         Husband   Asian-Pac-Islander
# 4   Married-civ-spouse     Other-service            Wife                Black
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country
# 0   Female             0          1902              40   United-States
# 1     Male         10520             0              45   United-States
# 2   Female             0             0              32   United-States
# 3     Male             0             0              40   United-States
# 4   Female             0             0              50   United-States

# %%
splits = RandomSplitter(valid_pct=0.2)(range_of(df))
to = TabularPandas(df.fillna(0), procs=[Categorify, FillMissing,Normalize],
                   cat_names = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race'],
                   cont_names = ['age', 'fnlwgt', 'education-num'],
                   y_names='salary',
                   splits=splits)
dls = to.dataloaders(bs=64)
dls.show_batch()
to.xs.iloc[:2]
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>workclass</th>
#       <th>education</th>
#       <th>marital-status</th>
#       <th>occupation</th>
#       <th>relationship</th>
#       <th>race</th>
#       <th>age</th>
#       <th>fnlwgt</th>
#       <th>education-num</th>
#       <th>salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Married-civ-spouse</td>
#       <td>Tech-support</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>27.0</td>
#       <td>188941.000006</td>
#       <td>1.000000e+01</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Private</td>
#       <td>Assoc-voc</td>
#       <td>Married-civ-spouse</td>
#       <td>Prof-specialty</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>45.0</td>
#       <td>259463.002506</td>
#       <td>1.100000e+01</td>
#       <td>&gt;=50k</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Private</td>
#       <td>Masters</td>
#       <td>Never-married</td>
#       <td>0</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>35.0</td>
#       <td>261293.000977</td>
#       <td>1.400000e+01</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>State-gov</td>
#       <td>Bachelors</td>
#       <td>Married-civ-spouse</td>
#       <td>Exec-managerial</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>43.0</td>
#       <td>139734.001094</td>
#       <td>1.300000e+01</td>
#       <td>&gt;=50k</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Self-emp-not-inc</td>
#       <td>HS-grad</td>
#       <td>Never-married</td>
#       <td>0</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>27.0</td>
#       <td>41099.003920</td>
#       <td>2.181264e-07</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Never-married</td>
#       <td>Transport-moving</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>26.0</td>
#       <td>389856.003950</td>
#       <td>9.000000e+00</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Widowed</td>
#       <td>Machine-op-inspct</td>
#       <td>Unmarried</td>
#       <td>Black</td>
#       <td>39.0</td>
#       <td>324231.004106</td>
#       <td>9.000000e+00</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Private</td>
#       <td>11th</td>
#       <td>Never-married</td>
#       <td>Other-service</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>18.0</td>
#       <td>78181.002837</td>
#       <td>7.000000e+00</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Married-civ-spouse</td>
#       <td>Adm-clerical</td>
#       <td>Wife</td>
#       <td>Black</td>
#       <td>53.0</td>
#       <td>335481.002273</td>
#       <td>9.000000e+00</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Married-civ-spouse</td>
#       <td>Other-service</td>
#       <td>Wife</td>
#       <td>Black</td>
#       <td>28.0</td>
#       <td>90546.997624</td>
#       <td>9.000000e+00</td>
#       <td>&lt;50k</td>
#     </tr>
#   </tbody>
# </table>
#        workclass  education  marital-status  occupation  relationship  race  \
# 3734           2         10               1           6             3     5
# 19678          5         12               3          10             1     5
#
#             age    fnlwgt  education-num
# 3734  -0.117066  0.172838       1.087889
# 19678  1.271040 -0.139572      -0.326433

# %%
learn = tabular_learner(dls, metrics=accuracy)

# %%
learn.fit_one_cycle(1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.367744</td>
#       <td>0.362312</td>
#       <td>0.837991</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>workclass</th>
#       <th>education</th>
#       <th>marital-status</th>
#       <th>occupation</th>
#       <th>relationship</th>
#       <th>race</th>
#       <th>age</th>
#       <th>fnlwgt</th>
#       <th>education-num</th>
#       <th>salary</th>
#       <th>salary_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.0</td>
#       <td>16.0</td>
#       <td>3.0</td>
#       <td>6.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>-0.409299</td>
#       <td>-0.536816</td>
#       <td>0.027147</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.0</td>
#       <td>12.0</td>
#       <td>3.0</td>
#       <td>16.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>-0.920706</td>
#       <td>-0.967862</td>
#       <td>-0.326433</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.0</td>
#       <td>8.0</td>
#       <td>5.0</td>
#       <td>7.0</td>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>0.394341</td>
#       <td>-0.687342</td>
#       <td>0.734308</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.0</td>
#       <td>13.0</td>
#       <td>1.0</td>
#       <td>14.0</td>
#       <td>2.0</td>
#       <td>5.0</td>
#       <td>2.586087</td>
#       <td>-0.993077</td>
#       <td>1.441470</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.0</td>
#       <td>12.0</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>0.905749</td>
#       <td>1.564735</td>
#       <td>-0.326433</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>7.0</td>
#       <td>10.0</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>1.197982</td>
#       <td>0.083271</td>
#       <td>-2.094336</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>5.0</td>
#       <td>16.0</td>
#       <td>1.0</td>
#       <td>7.0</td>
#       <td>2.0</td>
#       <td>5.0</td>
#       <td>0.248225</td>
#       <td>-1.271958</td>
#       <td>0.027147</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>10.0</td>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>-1.578230</td>
#       <td>0.469374</td>
#       <td>-1.387175</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>5.0</td>
#       <td>9.0</td>
#       <td>3.0</td>
#       <td>14.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>-0.482357</td>
#       <td>-0.398412</td>
#       <td>0.380728</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_df = df.copy()
test_df.drop(['salary'], axis=1, inplace=True)
dl = learn.dls.test_dl(test_df)

# %%
test_dl = learn.dls.test_dl(test_data.fillna(0)) # New dataloader with the test data
preds, _ = learn.get_preds(dl=test_dl)
preds = preds.numpy() # Convert to numpy array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5980\834026608.py in <module>
# ----> 1 test_dl = learn.dls.test_dl(aipred.fillna(0)) # New dataloader with the test data
#       2 preds, _ = learn.get_preds(dl=test_dl)
#       3 preds = preds.numpy() # Convert to numpy array
#
# NameError: name 'learn' is not defined

# %%
le = pd.read_csv(aipred)

# %%
le.data_head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18656\33480514.py in <module>
# ----> 1 le.data_head()
#
# ~\anaconda3\envs\fastai\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data_head'
